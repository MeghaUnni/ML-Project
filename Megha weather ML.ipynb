# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("WeatherData.csv")
df
# Out:
#     Temperature(C)  Humidity
# 0         9.472222      0.89
# 1         9.355556      0.86
# 2         9.377778      0.89
# 3         8.288889      0.83
# 4         8.755556      0.83
# 5         9.222222      0.85
# 6         7.733333      0.95
# 7         8.772222      0.89
# 8        10.822222      0.82
# 9        13.772222      0.72
# 10       16.016667      0.67
# 11       17.144444      0.54
# 12       17.800000      0.55
# 13       17.333333      0.51
# 14       18.877778      0.47
# 15       18.911111      0.46
# 16       15.388889      0.60
# 17       15.550000      0.63
# 18       14.255556      0.69
# 19       13.144444      0.70
# 20       11.550000      0.77
# 21       11.183333      0.76
# 22       10.116667      0.79
# 23       10.200000      0.77
# 24       10.422222      0.62
# 25        9.911111      0.66
# 26       11.183333      0.80
# 27        7.155556      0.79
# 28        6.111111      0.82
# 29        6.788889      0.83
# 30        7.261111      0.85
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Temperature(C)  50 non-null     float64
#  1   Humidity        50 non-null     float64
# dtypes: float64(2)
# memory usage: 928.0 bytes

# %%
df.corr()
# Out:
#                 Temperature(C)  Humidity
# Temperature(C)        1.000000 -0.943471
# Humidity             -0.943471  1.000000

# %%
df.isnull().sum()
# Out:
# Temperature(C)    0
# Humidity          0
# dtype: int64

# %%
xtem=df["Temperature(C)"]
yhu=df["Humidity"]
print(xtem)
print(yhu)
# Out:
# 0      9.472222
# 1      9.355556
# 2      9.377778
# 3      8.288889
# 4      8.755556
# 5      9.222222
# 6      7.733333
# 7      8.772222
# 8     10.822222
# 9     13.772222
# 10    16.016667
# 11    17.144444
# 12    17.800000
# 13    17.333333
# 14    18.877778
# 15    18.911111
# 16    15.388889
# 17    15.550000
# 18    14.255556
# 19    13.144444
# 20    11.550000
# 21    11.183333
# 22    10.116667
# 23    10.200000
# 24    10.422222
# 25     9.911111
# 26    11.183333
# 27     7.155556
# 28     6.111111
# 29     6.788889
# 30     7.261111
# 31     7.800000
# 32     9.872222
# 33    12.222222
# 34    15.094444
# 35    17.355556
# 36    19.005556
# 37    20.044444
# 38    21.050000
# 39    21.183333
# 40    20.116667
# 41    20.216667
# 42    20.000000
# 43    17.800000
# 44    16.061111
# 45    15.022222
# 46    14.422222
# 47    14.255556
# 48    13.772222
# 49    13.283333
# Name: Temperature(C), dtype: float64
# 0     0.89
# 1     0.86
# 2     0.89
# 3     0.83
# ...

# %%
xt=pd.DataFrame(xtem)
yh=pd.DataFrame(yhu)
print(xt,yh)
# Out:
#     Temperature(C)
# 0         9.472222
# 1         9.355556
# 2         9.377778
# 3         8.288889
# 4         8.755556
# 5         9.222222
# 6         7.733333
# 7         8.772222
# 8        10.822222
# 9        13.772222
# 10       16.016667
# 11       17.144444
# 12       17.800000
# 13       17.333333
# 14       18.877778
# 15       18.911111
# 16       15.388889
# 17       15.550000
# 18       14.255556
# 19       13.144444
# 20       11.550000
# 21       11.183333
# 22       10.116667
# 23       10.200000
# 24       10.422222
# 25        9.911111
# 26       11.183333
# 27        7.155556
# 28        6.111111
# 29        6.788889
# 30        7.261111
# 31        7.800000
# 32        9.872222
# 33       12.222222
# 34       15.094444
# 35       17.355556
# 36       19.005556
# 37       20.044444
# 38       21.050000
# 39       21.183333
# 40       20.116667
# 41       20.216667
# 42       20.000000
# 43       17.800000
# 44       16.061111
# 45       15.022222
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x1train,x1test,y1train,y1test=train_test_split(xt,yh,test_size=0.25,random_state=50)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
model=lr.fit(xt,yh)
ypr=model.predict(x1test)
print(y1test)
# Out:
#     Humidity
# 34      0.61
# 36      0.46
# 1       0.86
# 38      0.40
# 8       0.82
# 16      0.60
# 35      0.52
# 13      0.51
# 29      0.83
# 24      0.62
# 18      0.69
# 46      0.58
# 12      0.55

# %%
print(ypr)
# Out:
# [[0.6020417 ]
#  [0.46429037]
#  [0.8041683 ]
#  [0.39228399]
#  [0.75251155]
#  [0.59167122]
#  [0.52240421]
#  [0.52318689]
#  [0.8945676 ]
#  [0.76659975]
#  [0.63158779]
#  [0.62571771]
#  [0.50675065]]

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
print("MEan square is: ", mean_squared_error(y1test,ypr))
# Out:
# MEan square is:  0.003161173494187085

# %%
print("R square :", r2_score(y1test,ypr))
# Out:
# R square : 0.8354164138885959
